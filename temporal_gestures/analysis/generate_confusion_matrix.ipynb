# %% [markdown]
# # Confusion Matrices + Data from the Emperiment
#
# This notebook originally ran with python v3.9.
# The below analysis assumes 1 to equal "Gesture is Recognized" and 0 to equal "Gesture is not recognized".

# %% [markdown]
# ## Gesture 1: Slow-Fast-Fast

# %%
# We expect it to recognize the gesture every time (all true)
expected = ["SFF", 
            "SFF", 
            "SFF", 
            "SFF" , 
            "SFF", 
            "SFF", 
            "SFF" , 
            "SFF", 
            "SFF", 
            "SFF", 
            "SFF", 
            "SFF", 
            "SFF", 
            "SFF" , 
            "SFF", 
            "SFF", 
            "SFF" , 
            "SFF", 
            "SFF", 
            "SFF" ]

actual = [ "SFF",
           "SFF", 
           "No match", 
           "SFF", 
           "SFF", 
           "Speedup", 
           "SFF", 
           "SFF", 
           "Speedup", 
           "Slowdown", 
           "Speedup", 
           "Speedup", 
           "Speedup", 
           "SFF", 
           "SFF",
           "SFF", 
           "Speedup", 
           "SFF", 
           "Speedup", 
           "SFF"]

# %% [markdown]
# ## Gesture 2: Fast-Fast-Slow

# %%
expected.extend([
    "FSS", 
    "FSS", 
    "FSS", 
    "FSS", 
    "FSS", 
    "FSS",
    "FSS", 
    "FSS",
    "FSS", 
    "FSS",
    "FSS", 
    "FSS", 
    "FSS", 
    "FSS",
    "FSS", 
    "FSS",
    "FSS", 
    "FSS",
    "FSS", 
    "FSS"  
])

actual.extend([
    "Stable",
    "Stable",
    "Stable", 
    "FPFF",
    "Speedup", 
    "Stable", 
    "Square", 
    "FFS", 
    "FFS", 
    "FFS", 
    "Stable", 
    "Stable", 
    "Stable", 
    "Stable", 
    "Square",
    "Square",
    "Square",
    "Square",
    "Square",
    "Square", 
    "Stable", 
    "Square"
])

# %% [markdown]
# ## Gesture 3: Fast-Pause-Fast-Fast

# %%
expected.extend([
    "FPFF", 
    "FPFF", 
    "FPFF", 
    "FPFF", 
    "FPFF", 
    "FPFF", 
    "FPFF", 
    "FPFF", 
    "FPFF", 
    "FPFF",     
    "FPFF", 
    "FPFF", 
    "FPFF", 
    "FPFF", 
    "FPFF",     
    "FPFF", 
    "FPFF", 
    "FPFF", 
    "FPFF", 
    "FPFF" 
])

actual.extend([
    "FPFF",
    "FPFF", 
    "FPFF"
    "No match",
    "Slowdown",
    "FPFF",
    "FPFF",
    "No match",
    "No match",
    "FPFF",
    "FPFF",
    "FPFF",
    "FPFF",
    "FPFF",
    "FPFF",
    "No match",
    "FPFF",
    "FPFF",
    "FPFF",
    "FPFF"
])

# %% [markdown]
# ## Gesture 4: Fast-Fast-Pause-Fast

# %%
expected.extend([
    "FFPF", 
    "FFPF", 
    "FFPF", 
    "FFPF", 
    "FFPF", 
    "FFPF", 
    "FFPF", 
    "FFPF", 
    "FFPF", 
    "FFPF", 
    "FFPF", 
    "FFPF", 
    "FFPF", 
    "FFPF", 
    "FFPF", 
    "FFPF", 
    "FFPF", 
    "FFPF", 
    "FFPF", 
    "FFPF"
])

actual.extend([
    "No match",
    "FFPF",
    "No match",
    "No match",
    "No match",
    "FPFF",
    "FPFF",
    "No match",
    "FPFF",
    "No match", 
    "No match", 
    "No match",
    "No match", 
    "FPFF",
    "No match",
    "No match",
    "No match",
    "FPFF",
    "No match", 
    "FPFF",
])

# %% [markdown]
# ## Gesture 5: Stable

# %%
expected.extend([
    "Stable",
    "Stable",
    "Stable",
    "Stable",
    "Stable",
    "Stable",
    "Stable",
    "Stable",
    "Stable",
    "Stable",
    "Stable",
    "Stable",
    "Stable",
    "Stable",
    "Stable",
    "Stable",
    "Stable",
    "Stable",
    "Stable",
    "Stable"
])

actual.extend([
    "Stable",
    "Stable",
    "Stable",
    "Stable",
    "Square",
    "FFS",
    "Stable",
    "Square",
    "Square,"
    "Stable",
    "Square",
    "Stable",
    "Stable",
    "Square",
    "Square", 
    "FFS",
    "Stable",
    "Square",
    "Stable",
    "Stable"
])

# %% [markdown]
# ## Gesture 6: Speedup

# %%
expected.extend([
    "Speedup",
    "Speedup",
    "Speedup",
    "Speedup",
    "Speedup",
    "Speedup",
    "Speedup",
    "Speedup",
    "Speedup",
    "Speedup",
    "Speedup",
    "Speedup",
    "Speedup",
    "Speedup",
    "Speedup",
    "Speedup",
    "Speedup",
    "Speedup",
    "Speedup",
    "Speedup"
])

actual.extend([
    "SFF",
    "SFF",
    "FFS",
    "FFS",
    "Speedup",
    "FPFF",
    "SFF",
    "FFS",
    "Speedup",
    "Speedup",
    "Speedup", 
    "Square",
    "Speedup",
    "Speedup",
    "Speedup",
    "Speedup",
    "Stable",
    "FFS",
    "Stable",
    "Stable"
])

# %% [markdown]
# ## Gesture 7: Slowdown

# %%
expected.extend([
    "Slowdown",
    "Slowdown",
    "Slowdown",
    "Slowdown",
    "Slowdown",
    "Slowdown",
    "Slowdown",
    "Slowdown",
    "Slowdown",
    "Slowdown",
    "Slowdown",
    "Slowdown",
    "Slowdown",
    "Slowdown",
    "Slowdown",
    "Slowdown",
    "Slowdown",
    "Slowdown",
    "Slowdown",
    "Slowdown",

])

actual.extend([
    "Slowdown",
    "Square",
    "FFPF",
    "Stable",
    "Stable",
    "Square",
    "Stable",
    "FFS",
    "Stable",
    "Slowdown",
    "Square",
    "Square",
    "Square",
    "No match",
    "No match",
    "Slowdown",
    "Slowdown",
    "Slowdown",
    "No match",
    "Slowdown"
])

# %% [markdown]
# ## Gesture 8: Square

# %%
expected.extend([
    "Square",
    "Square",
    "Square",
    "Square",
    "Square",
    "Square",
    "Square",
    "Square",
    "Square",
    "Square",
    "Square",
    "Square",
    "Square",
    "Square",
    "Square",
    "Square",
    "Square",
    "Square",
    "Square",
    "Square"
])

actual.extend([
    "Square",
    "Stable",
    "Square",
    "Square",
    "Square",
    "Square",
    "Stable",
    "Stable",
    "Stable",
    "Square",
    "Stable",
    "Stable",
    "FPFF",
    "Square",
    "Square",
    "Square",
    "FFS",
    "Square",
    "Square",
    "FFS"
])

# %% [markdown]
# ## Generate Confusion Matrix

# %%
import seaborn as sns
import matplotlib.pyplot as plt    
from sklearn.metrics import confusion_matrix 

GESTURE_NAMES = ["FFS", "SFF", "FPFF", "FFPF", "Stable", "Speedup", "Slowdown", "Square", "No match"]
cm = confusion_matrix(expected, actual, labels =GESTURE_NAMES)

sns.set_theme(rc={"figure.figsize": (15, 12)})

ax= plt.subplot()
fig = sns.heatmap(cm, annot=True, fmt='g', ax=ax);  # 'g' disables scientific notation




# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(GESTURE_NAMES); ax.yaxis.set_ticklabels(GESTURE_NAMES)

plt.savefig("./confusion_matrix.png")
